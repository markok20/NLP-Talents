# %%
# NLP Talents Team Projects Preprocessing notebook 3

import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# data in

data = pd.read_csv('newdata.csv')
data.tail(10)
# Out:
#         Unnamed: 0                Date       Screen Name  \
# 286467      868176  3/20/2021 18:45:05   @jetairways2021
# 286468      868241  3/22/2021 15:07:55   @Aviation_jamie
# 286469      868268  3/22/2021 21:54:11  @Antoine71284847
# 286470      868290  3/23/2021 16:05:01          @Fede282
# 286471      868297  3/23/2021 19:11:27  @TurksonEmmanu13
# 286472      868309  3/23/2021 21:21:43        @AirbusRed
# 286473      868344  3/24/2021 13:56:49       @lou26chris
# 286474      868346  3/24/2021 15:03:10       @lou26chris
# 286475      868347  3/24/2021 15:06:29       @lou26chris
# 286476      868350  3/24/2021 15:59:14  @PeterButterfi12
#
#                            Full Name  \
# 286467              Jet Airways 2021
# 286468                             J
# 286469  ??BeeCharmer ?? Earthling ??
# 286470               Federico Foggia
# 286471            WHOLE LOTTA PAIN??
# 286472                     AirbusRed
# 286473                  louisa hardy
# ...

# %%
# 286 477 rows, 19 columns)

data.shape
# Out:
# (286477, 19)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Screen Name', 'Full Name', 'Tweet Text',
#        'Tweet ID', 'App', 'Followers', 'Follows', 'Retweets', 'Favorites',
#        'Verfied', 'User Since', 'Location', 'Bio', 'Profile Image',
#        'Airport_Twitter_Tag', 'Airport_IATA_Codes', 'Airport_Names'],
#       dtype='object')

# %%
# dropping columns away

data.drop(['Screen Name', 'Full Name', 'Tweet ID', 'App', 'Verfied', 'User Since', 'Location', 'Bio', 'Profile Image'], axis = 1, inplace = True)
data.head()
# Out:
#    Unnamed: 0                 Date  \
# 0       15421        4/7/2017 7:52
# 1       25645      12/3/2018 14:06
# 2       88734  12/24/2020 19:34:34
# 3      181260    6/12/2020 0:33:26
# 4      262833    8/29/2020 0:36:32
#
#                                           Tweet Text  Followers  Follows  \
# 0  Update: Flt EI7RE departed back to Dublin at 0...    20959.0    240.0
# 1  @DublinAirport Ah lads come on, rally the troo...     1433.0    637.0
# 2             @DublinAirport https://t.co/8XPuZnW0P9    27616.0    868.0
# 3  @brskyrme @VirginAtlantic @HeathrowAirport @br...    51130.0   3181.0
# 4  @JetSetGOConnor @flykkylie @HeathrowAirport @S...    27451.0    452.0
#
#    Retweets  Favorites Airport_Twitter_Tag Airport_IATA_Codes  \
# 0       0.0        0.0      @dublinairport                DUB
# 1       0.0        0.0      @dublinairport                DUB
# 2       0.0        0.0      @dublinairport                DUB
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.Airport_Twitter_Tag.value_counts()
# Out:
# @heathrowairport    84237
# @manairport         68328
# @dublinairport      53103
# @gatwick_airport    43548
# @stn_airport        37261
# Name: Airport_Twitter_Tag, dtype: int64

# %%
data.describe()
# Out:
#           Unnamed: 0     Followers       Follows       Retweets      Favorites
# count  286477.000000  2.864770e+05  2.864770e+05  286477.000000  286477.000000
# mean   507289.241503  2.040953e+03  1.149240e+03       1.952443       0.080635
# std    146786.334146  4.146320e+04  4.907164e+03      68.906499       0.525875
# min     15421.000000  0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    389173.000000  4.400000e+01  1.370000e+02       0.000000       0.000000
# 50%    491824.000000  1.900000e+02  4.010000e+02       0.000000       0.000000
# 75%    607836.000000  6.810000e+02  1.133000e+03       0.000000       0.000000
# max    868350.000000  8.017900e+06  1.011585e+06    9527.000000     106.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286477 entries, 0 to 286476
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           286477 non-null  int64
#  1   Date                 286477 non-null  object
#  2   Tweet Text           286477 non-null  object
#  3   Followers            286477 non-null  float64
#  4   Follows              286477 non-null  float64
#  5   Retweets             286477 non-null  float64
#  6   Favorites            286477 non-null  float64
#  7   Airport_Twitter_Tag  286477 non-null  object
#  8   Airport_IATA_Codes   286477 non-null  object
#  9   Airport_Names        286477 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 21.9+ MB
